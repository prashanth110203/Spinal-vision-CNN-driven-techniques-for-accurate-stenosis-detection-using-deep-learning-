# %%
# !pip install diffusers transformers accelerate

from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch


model_id1 = "dreamlike-art/dreamlike-diffusion-1.0"


pipe = StableDiffusionPipeline.from_pretrained(model_id1, torch_dtype=torch.float32)  

pipe = pipe.to("cpu")

# Define the prompt
prompt = """dreamlikeart, a grungy woman with rainbow hair, travelling between dimensions, dynamic pose, happy, soft eyes and narrow chin,
extreme bokeh, dainty figure, long hair straight down, torn kawaii shirt and baggy jeans"""

# Generate the image on CPU
image = pipe(prompt).images[0]

# Display the image
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Collecting diffusers
#   Using cached diffusers-0.32.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers in d:\software\anaconda\envs\pro\lib\site-packages (4.47.0.dev0)
# Requirement already satisfied: accelerate in d:\software\anaconda\envs\pro\lib\site-packages (1.1.1)
# Requirement already satisfied: importlib-metadata in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (6.8.0)
# Requirement already satisfied: filelock in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (0.26.3)
# Requirement already satisfied: numpy in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (2023.8.8)
# Requirement already satisfied: requests in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in d:\software\anaconda\envs\pro\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in d:\software\anaconda\envs\pro\lib\site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\software\anaconda\envs\pro\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\software\anaconda\envs\pro\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: networkx in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\software\anaconda\envs\pro\lib\site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\software\anaconda\envs\pro\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in d:\software\anaconda\envs\pro\lib\site-packages (from importlib-metadata->diffusers) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2022.12.7)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'd:\\software\\anaconda\\envs\\pro\\lib\\site-packages\\urllib3-2.2.3.dist-info\\METADATA'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 get_ipython().system('pip install diffusers transformers accelerate')
# ----> 3 from diffusers import StableDiffusionPipeline
#       4 import matplotlib.pyplot as plt
#       5 import torch
#
# ModuleNotFoundError: No module named 'diffusers'

# %%
pip install --upgrade pip setuptools
# Out:
#   Cell In[9], line 2
#     pip uninstall urllib3
#         ^
# SyntaxError: invalid syntax

# %%
# !pip uninstall urllib3
# !pip install urllib3
# Out:
# Found existing installation: urllib3 2.2.3
# WARNING: No metadata found in d:\software\anaconda\envs\pro\lib\site-packages
# error: uninstall-no-record-file
#
# Cannot uninstall urllib3 2.2.3
#
# The package's contents are unknown: no RECORD file was found for urllib3.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps urllib3==2.2.3
# Requirement already satisfied: urllib3 in d:\software\anaconda\envs\pro\lib\site-packages (2.2.3)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'd:\\software\\anaconda\\envs\\pro\\lib\\site-packages\\urllib3-2.2.3.dist-info\\METADATA'

# %%
pip install diffusers transformers accelerate
# Out:
# Collecting diffusers
#   Using cached diffusers-0.32.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers in d:\software\anaconda\envs\pro\lib\site-packages (4.47.0.dev0)
# Requirement already satisfied: accelerate in d:\software\anaconda\envs\pro\lib\site-packages (1.1.1)
# Requirement already satisfied: importlib-metadata in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (6.8.0)
# Requirement already satisfied: filelock in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (0.26.3)
# Requirement already satisfied: numpy in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (2023.8.8)
# Requirement already satisfied: requests in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in d:\software\anaconda\envs\pro\lib\site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in d:\software\anaconda\envs\pro\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: psutil in d:\software\anaconda\envs\pro\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in d:\software\anaconda\envs\pro\lib\site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\software\anaconda\envs\pro\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\software\anaconda\envs\pro\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: networkx in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in d:\software\anaconda\envs\pro\lib\site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\software\anaconda\envs\pro\lib\site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\software\anaconda\envs\pro\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in d:\software\anaconda\envs\pro\lib\site-packages (from importlib-metadata->diffusers) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\envs\pro\lib\site-packages (from requests->diffusers) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'd:\\software\\anaconda\\envs\\pro\\lib\\site-packages\\urllib3-2.2.3.dist-info\\METADATA'

# %%
pip show diffusers transformers accelerate
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: diffusers
# ERROR: Exception:
# Traceback (most recent call last):
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3367, in _dep_map
#     return self.__dep_map
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3147, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3358, in _parsed_pkg_info
#     return self._pkg_info
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3147, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\commands\show.py", line 46, in run
#     if not print_results(
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\commands\show.py", line 178, in print_results
#     for i, dist in enumerate(distributions):
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\commands\show.py", line 114, in search_packages_info
#     required_by = sorted(_get_requiring_packages(dist), key=str.lower)
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\commands\show.py", line 95, in <genexpr>
#     in {canonicalize_name(d.name) for d in dist.iter_dependencies()}
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_internal\metadata\pkg_resources.py", line 247, in iter_dependencies
#     return self._dist.requires(extras)
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3070, in requires
#     dm = self._dep_map
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3369, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3378, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3360, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1672, in get_metadata
#     value = self._get(path)
#   File "D:\SOFTWARE\ANACONDA\envs\pro\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 1886, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\software\\anaconda\\envs\\pro\\lib\\site-packages\\urllib3-2.2.3.dist-info\\METADATA'

# %%
# !pip uninstall urllib3
# Out:
# Found existing installation: urllib3 2.2.3
# WARNING: No metadata found in d:\software\anaconda\envs\pro\lib\site-packages
# error: uninstall-no-record-file
#
# Cannot uninstall urllib3 2.2.3
#
# The package's contents are unknown: no RECORD file was found for urllib3.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps urllib3==2.2.3
